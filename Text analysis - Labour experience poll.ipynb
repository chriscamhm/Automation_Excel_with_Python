# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
def normalize(s):
    replacements=(
    ("á","a"),
    ("é","e"),
    ("í","i"),
    ("ó","o"),
    ("ú","u"),
    )
    for a,b in replacements:
        s = s.replace(a,b).replace(a.upper(),b.upper())
    return s

# %%
df_c=pd.read_excel('comentarios totales ecopetrol abiertos.xlsx', sheet_name='comenzar')
df_c
# Out:
#                                    Texto de la pregunta  \
# 0     ¿Qué considera que el Grupo Ecopetrol debe emp...
# 1     ¿Qué considera que el Grupo Ecopetrol debe emp...
# 2     ¿Qué considera que el Grupo Ecopetrol debe emp...
# 3     ¿Qué considera que el Grupo Ecopetrol debe emp...
# 4     ¿Qué considera que el Grupo Ecopetrol debe emp...
# ...                                                 ...
# 8302  ¿Qué considera que el Grupo Ecopetrol debe emp...
# 8303  ¿Qué considera que el Grupo Ecopetrol debe emp...
# 8304  ¿Qué considera que el Grupo Ecopetrol debe emp...
# 8305  ¿Qué considera que el Grupo Ecopetrol debe emp...
# 8306  ¿Qué considera que el Grupo Ecopetrol debe emp...
#
#                                              Comentario  \
# 0     Mayor énfasis en el desarrollo profesional de ...
# 1     Solicitar a los jefes proyectos que demuestren...
# 2     Estudiar y escuchar a la población objetiva, s...
# 3     En mi opinión pienso que en el último año, la ...
# 4     Debe cada vez más promover los intereses de su...
# ...                                                 ...
# 8302  Continuar con las actividades que se generan e...
# 8303  Considero importante seguir fortaleciendo el c...
# 8304  Continuar en la senda de transformación siempr...
# 8305  Fortalecer el cambio cultural hacia la transfo...
# 8306  espacios de esparcimiento y gran apoyo para po...
#
#                            Clasificación de comentarios
# 0     Oportunidades de carrera / Desarrollo profesional
# 1     Oportunidades de carrera / Desarrollo profesional
# 2     Oportunidades de carrera / Desarrollo profesional
# 3                                      Liderazgo senior
# 4                   Conciliación laboral y flexibilidad
# ...                                                 ...
# 8302  Oportunidades de carrera / Desarrollo profesional
# 8303                                     Comunicaciones
# 8304                                              Otros
# 8305                Herramientas, tecnología y recursos
# 8306                Conciliación laboral y flexibilidad
#
# [8307 rows x 3 columns]

# %%
df_d=pd.read_excel('comentarios totales ecopetrol abiertos.xlsx', sheet_name='dejar')
df_d
# Out:
#                                    Texto de la pregunta  \
# 0     ¿Qué considera que el Grupo Ecopetrol debe dej...
# 1     ¿Qué considera que el Grupo Ecopetrol debe dej...
# 2     ¿Qué considera que el Grupo Ecopetrol debe dej...
# 3     ¿Qué considera que el Grupo Ecopetrol debe dej...
# 4     ¿Qué considera que el Grupo Ecopetrol debe dej...
# ...                                                 ...
# 8297  ¿Qué considera que el Grupo Ecopetrol debe dej...
# 8298  ¿Qué considera que el Grupo Ecopetrol debe dej...
# 8299  ¿Qué considera que el Grupo Ecopetrol debe dej...
# 8300  ¿Qué considera que el Grupo Ecopetrol debe dej...
# 8301  ¿Qué considera que el Grupo Ecopetrol debe dej...
#
#                                              Comentario  \
# 0     Abrir menos procesos externos y más internos o...
# 1     Acciones que sean tangibles con el tiempo Ejem...
# 2     Ecopetrol no, el personal que lidera nuestra o...
# 3     Me parece que todo lo esta haciendo muy bien, ...
# 4     Veo frecuente, una competencia entre los mismo...
# ...                                                 ...
# 8297  Creo que en particular la vicepresidencia dond...
# 8298  generar equilibrio de su personal entre el tra...
# 8299  mantenerse distante con el personal que esta d...
# 8300  El grupo Ecopetrol debe revisar el rol y funci...
# 8301  Dejar de propender por la planeación de trabaj...
#
#                            Clasificación de comentarios
# 0     Oportunidades de carrera / Desarrollo profesional
# 1                               Orientación estratégica
# 2     Oportunidades de carrera / Desarrollo profesional
# 3                                                 Otros
# 4                   Conciliación laboral y flexibilidad
# ...                                                 ...
# 8297                Entorno laboral y trato al empleado
# 8298                                 Superior inmediato
# 8299  Oportunidades de carrera / Desarrollo profesional
# 8300              Mi trabajo / el trabajo que desempeño
# 8301                Entorno laboral y trato al empleado
#
# [8302 rows x 3 columns]

# %%
df_c['dup'] = df_c.duplicated(subset=None, keep='first')
df_c = df_c[df_c['dup'] == False]
df_c
# Out:
#                                    Texto de la pregunta  \
# 0     ¿Qué considera que el Grupo Ecopetrol debe emp...
# 1     ¿Qué considera que el Grupo Ecopetrol debe emp...
# 2     ¿Qué considera que el Grupo Ecopetrol debe emp...
# 3     ¿Qué considera que el Grupo Ecopetrol debe emp...
# 4     ¿Qué considera que el Grupo Ecopetrol debe emp...
# ...                                                 ...
# 8302  ¿Qué considera que el Grupo Ecopetrol debe emp...
# 8303  ¿Qué considera que el Grupo Ecopetrol debe emp...
# 8304  ¿Qué considera que el Grupo Ecopetrol debe emp...
# 8305  ¿Qué considera que el Grupo Ecopetrol debe emp...
# 8306  ¿Qué considera que el Grupo Ecopetrol debe emp...
#
#                                              Comentario  \
# 0     Mayor énfasis en el desarrollo profesional de ...
# 1     Solicitar a los jefes proyectos que demuestren...
# 2     Estudiar y escuchar a la población objetiva, s...
# 3     En mi opinión pienso que en el último año, la ...
# 4     Debe cada vez más promover los intereses de su...
# ...                                                 ...
# 8302  Continuar con las actividades que se generan e...
# 8303  Considero importante seguir fortaleciendo el c...
# 8304  Continuar en la senda de transformación siempr...
# 8305  Fortalecer el cambio cultural hacia la transfo...
# 8306  espacios de esparcimiento y gran apoyo para po...
#
#                            Clasificación de comentarios    dup
# 0     Oportunidades de carrera / Desarrollo profesional  False
# 1     Oportunidades de carrera / Desarrollo profesional  False
# 2     Oportunidades de carrera / Desarrollo profesional  False
# 3                                      Liderazgo senior  False
# 4                   Conciliación laboral y flexibilidad  False
# ...                                                 ...    ...
# 8302  Oportunidades de carrera / Desarrollo profesional  False
# 8303                                     Comunicaciones  False
# 8304                                              Otros  False
# 8305                Herramientas, tecnología y recursos  False
# 8306                Conciliación laboral y flexibilidad  False
#
# [8112 rows x 4 columns]

# %%
terms1 = ['vida personal', 'familia', 'familiares', 'horario', 'tiempo libre', 'vida laboral', 'balance','descanso','reuniones','reunión','equilibrio']
df_c= df_c[df_c['Comentario'].str.contains('|'.join(terms1), na=False)]
df_c
# Out:
#                                    Texto de la pregunta  \
# 4     ¿Qué considera que el Grupo Ecopetrol debe emp...
# 13    ¿Qué considera que el Grupo Ecopetrol debe emp...
# 14    ¿Qué considera que el Grupo Ecopetrol debe emp...
# 18    ¿Qué considera que el Grupo Ecopetrol debe emp...
# 21    ¿Qué considera que el Grupo Ecopetrol debe emp...
# ...                                                 ...
# 8269  ¿Qué considera que el Grupo Ecopetrol debe emp...
# 8280  ¿Qué considera que el Grupo Ecopetrol debe emp...
# 8283  ¿Qué considera que el Grupo Ecopetrol debe emp...
# 8296  ¿Qué considera que el Grupo Ecopetrol debe emp...
# 8306  ¿Qué considera que el Grupo Ecopetrol debe emp...
#
#                                              Comentario  \
# 4     Debe cada vez más promover los intereses de su...
# 13    balancear la jornada de trabajo de 12 horas co...
# 14    Mantener las condiciones actuales de sus traba...
# 18    Con el fin de ser apasionados por la excelenci...
# 21    Lograr tener un adecuado balance vida Laboral ...
# ...                                                 ...
# 8269  Buscar que los turnos laborales del personal d...
# 8280  Hacer que los líderes sean coherentes con ella...
# 8283  Seguir fortaleciendo la familia Ecopetrol en t...
# 8296  La Alta Dirección debe ser totalmente transpar...
# 8306  espacios de esparcimiento y gran apoyo para po...
#
#                            Clasificación de comentarios    dup
# 4                   Conciliación laboral y flexibilidad  False
# 13                  Conciliación laboral y flexibilidad  False
# 14                     Sueldo, beneficios y recompensas  False
# 18                                                Otros  False
# 21    Oportunidades de carrera / Desarrollo profesional  False
# ...                                                 ...    ...
# 8269                                              Otros  False
# 8280                Entorno laboral y trato al empleado  False
# 8283  Oportunidades de carrera / Desarrollo profesional  False
# 8296                                              Otros  False
# 8306                Conciliación laboral y flexibilidad  False
#
# [967 rows x 4 columns]

# %%
import nltk
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize


example_sent = "Hola, soy Cristian y esto es la cosa"
stop_words = set(stopwords.words('spanish'))
word_tokens = word_tokenize(example_sent)

filtered_sentence = [w for w in word_tokens if not w in stop_words]
print(filtered_sentence)
# Out:
# ['Hola', ',', 'Cristian', 'cosa']

# %%
# Import the package
import stanza
stanza.download('es')
nlp = stanza.Pipeline('es')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.0.json:   0%|   …
# 2022-06-01 13:36:24 INFO: Downloading default packages for language: es (Spanish)...
# INFO:stanza:Downloading default packages for language: es (Spanish)...
# 2022-06-01 13:36:27 INFO: File exists: C:\Users\E0301558\stanza_resources\es\default.zip
# INFO:stanza:File exists: C:\Users\E0301558\stanza_resources\es\default.zip
# 2022-06-01 13:36:34 INFO: Finished downloading models and saved to C:\Users\E0301558\stanza_resources.
# INFO:stanza:Finished downloading models and saved to C:\Users\E0301558\stanza_resources.
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.0.json:   0%|   …
# 2022-06-01 13:36:36 INFO: Loading these models for language: es (Spanish):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | ancora  |
# | mwt       | ancora  |
# | pos       | ancora  |
# | lemma     | ancora  |
# | depparse  | ancora  |
# | ner       | conll02 |
# =======================
#
# INFO:stanza:Loading these models for language: es (Spanish):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | ancora  |
# | mwt       | ancora  |
# | pos       | ancora  |
# | lemma     | ancora  |
# | depparse  | ancora  |
# | ner       | conll02 |
# =======================
#
# 2022-06-01 13:36:36 INFO: Use device: cpu
# INFO:stanza:Use device: cpu
# 2022-06-01 13:36:36 INFO: Loading: tokenize
# INFO:stanza:Loading: tokenize
# 2022-06-01 13:36:36 INFO: Loading: mwt
# INFO:stanza:Loading: mwt
# 2022-06-01 13:36:36 INFO: Loading: pos
# INFO:stanza:Loading: pos
# 2022-06-01 13:36:37 INFO: Loading: lemma
# INFO:stanza:Loading: lemma
# 2022-06-01 13:36:37 INFO: Loading: depparse
# INFO:stanza:Loading: depparse
# 2022-06-01 13:36:37 INFO: Loading: ner
# INFO:stanza:Loading: ner
# 2022-06-01 13:36:39 INFO: Done loading processors!
# INFO:stanza:Done loading processors!

# %%
terms2 = ['vida personal', 'familia', 'familiares', 'horario', 'tiempo libre', 'vida laboral', 'balance','descanso','reuniones','reunión','equilibrio']
def preprocess(raw_text):
    
    stop_words = set(stopwords.words('spanish'))
    raw_text= normalize(raw_text)
    
    #regular expression keeping only letters 
    letters_only_text = re.sub("[^a-zA-Z]", " ", raw_text)

    # convert to lower case and split into words -> convert string into list ( 'hello world' -> ['hello', 'world'])
    words = letters_only_text.lower().split()
    
    cleaned_words = []
    
    # remove stopwords
    for word in words:
        if word not in stop_words:
            cleaned_words.append(word)
    #cleaned_words= []
    #for word in cleaned_word:
        #if word in terms2:
            #cleaned_words.append(word)
    
    # stemm or lemmatise words
    stemmed_words = []
    for w in cleaned_words:
        doc = nlp(w) #dont forget to change stem to lemmatize if you are using a lemmatizer
        for sent in doc.sentences:
            for word in sent.words:
                stemmed_words.append(word.lemma)
    
    # converting list back to string
    return " ".join(stemmed_words)

# %%
test_sentence = "Esta es una oración para demostrar como el preproceso funciona horario vida personal familiar...!"
preprocess(test_sentence)
# Out:
# 'oracion demostrar preproceso funcionar horario vida personal familiar'

# %%
df_c['Comentario']=df_c['Comentario'].apply(lambda x: str(x))
df_c['lemma']=df_c['Comentario'].apply(preprocess)
df_c
# Out:
#                                    Texto de la pregunta  \
# 4     ¿Qué considera que el Grupo Ecopetrol debe emp...
# 13    ¿Qué considera que el Grupo Ecopetrol debe emp...
# 14    ¿Qué considera que el Grupo Ecopetrol debe emp...
# 18    ¿Qué considera que el Grupo Ecopetrol debe emp...
# 21    ¿Qué considera que el Grupo Ecopetrol debe emp...
# ...                                                 ...
# 8269  ¿Qué considera que el Grupo Ecopetrol debe emp...
# 8280  ¿Qué considera que el Grupo Ecopetrol debe emp...
# 8283  ¿Qué considera que el Grupo Ecopetrol debe emp...
# 8296  ¿Qué considera que el Grupo Ecopetrol debe emp...
# 8306  ¿Qué considera que el Grupo Ecopetrol debe emp...
#
#                                              Comentario  \
# 4     Debe cada vez más promover los intereses de su...
# 13    balancear la jornada de trabajo de 12 horas co...
# 14    Mantener las condiciones actuales de sus traba...
# 18    Con el fin de ser apasionados por la excelenci...
# 21    Lograr tener un adecuado balance vida Laboral ...
# ...                                                 ...
# 8269  Buscar que los turnos laborales del personal d...
# 8280  Hacer que los líderes sean coherentes con ella...
# 8283  Seguir fortaleciendo la familia Ecopetrol en t...
# 8296  La Alta Dirección debe ser totalmente transpar...
# 8306  espacios de esparcimiento y gran apoyo para po...
#
#                            Clasificación de comentarios    dup  \
# 4                   Conciliación laboral y flexibilidad  False
# 13                  Conciliación laboral y flexibilidad  False
# 14                     Sueldo, beneficios y recompensas  False
# 18                                                Otros  False
# 21    Oportunidades de carrera / Desarrollo profesional  False
# ...                                                 ...    ...
# 8269                                              Otros  False
# 8280                Entorno laboral y trato al empleado  False
# 8283  Oportunidades de carrera / Desarrollo profesional  False
# 8296                                              Otros  False
# 8306                Conciliación laboral y flexibilidad  False
#
#                                                   lemma
# 4     deber cada vez mas promover interés trabajador...
# 13         balancear jornada trabajo hora vida familiar
# 14    mantener condición actual trabajador permitir ...
# 18    fin ser apasionado excelencia considerar deber...
# 21    lograr tener adecuado balance vida laboral vid...
# ...                                                 ...
# 8269  buscar turno laboral personal campo posterior ...
# 8280  hacer lider coherente servir tener principio c...
# 8283  seguir fortalecer familia ecopetrol ambito per...
# 8296  alto direccion deber ser totalmente transparen...
# 8306  espacio esparcimiento gran apoyo poder tener m...
#
# [967 rows x 5 columns]

# %%
from collections import Counter
Counter(" ".join(df_c["lemma"]).split()).most_common(15)
# Out:
# [('laboral', 558),
#  ('trabajo', 555),
#  ('vida', 517),
#  ('personal', 513),
#  ('deber', 400),
#  ('mas', 400),
#  ('balance', 284),
#  ('hacer', 283),
#  ('trabajador', 279),
#  ('familia', 276),
#  ('tiempo', 258),
#  ('poder', 234),
#  ('empresa', 224),
#  ('seguir', 217),
#  ('equilibrio', 215)]

# %%
df_d['dup'] = df_d.duplicated(subset=None, keep='first')
df_d = df_d[df_d['dup'] == False]
df_d= df_d[df_d['Comentario'].str.contains('|'.join(terms1), na=False)]
df_d['Comentario']=df_d['Comentario'].apply(lambda x: str(x))
df_d['lemma']=df_d['Comentario'].apply(preprocess)
from collections import Counter
Counter(" ".join(df_d["lemma"]).split()).most_common(15)
# Out:
# [('laboral', 300),
#  ('deber', 297),
#  ('trabajo', 285),
#  ('personal', 245),
#  ('reunión', 243),
#  ('mas', 236),
#  ('vida', 215),
#  ('tiempo', 213),
#  ('hacer', 165),
#  ('horario', 160),
#  ('familia', 145),
#  ('dejar', 145),
#  ('poder', 143),
#  ('él', 122),
#  ('ser', 111)]

# %%
all_words_c = '' 

#looping through all incidents and joining them to one text, to extract most common words
for arg in df_c["lemma"]: 

    tokens = arg.split()  
      
    all_words_c += " ".join(tokens)+" "

# %%
from nltk.util import ngrams
n_gram = 2
n_gram_dic = dict(Counter(ngrams(all_words_c.split(), n_gram)))

for i in n_gram_dic:
    if n_gram_dic[i] >= 50:
        print(i, n_gram_dic[i])
# Out:
# ('compa', 'ia') 68
# ('balance', 'vida') 162
# ('vida', 'laboral') 155
# ('vida', 'personal') 192
# ('equilibrio', 'vida') 96
# ('principio', 'cultural') 76
# ('deber', 'seguir') 53
# ('carga', 'laboral') 73
# ('personal', 'laboral') 91
# ('trabajo', 'remoto') 55
# ('laboral', 'personal') 106
# ('ecopetrol', 'deber') 52

# %%
all_words_d = '' 

#looping through all incidents and joining them to one text, to extract most common words
for arg in df_d["lemma"]: 

    tokens = arg.split()  
      
    all_words_d += " ".join(tokens)+" "

from nltk.util import ngrams
n_gram = 2
n_gram_dic = dict(Counter(ngrams(all_words_d.split(), n_gram)))

for i in n_gram_dic:
    if n_gram_dic[i] >= 30:
        print(i, n_gram_dic[i])
# Out:
# ('compa', 'ia') 39
# ('deber', 'dejar') 73
# ('laboral', 'personal') 53
# ('horario', 'laboral') 49
# ('equilibrio', 'vida') 37
# ('vida', 'personal') 79
# ('balance', 'vida') 62
# ('vida', 'laboral') 62
# ('carga', 'laboral') 45

# %%
pd.set_option("display.max_columns", None)
pd.set_option('display.max_colwidth', None)

# %%
terms3 = ['respetar horario trabajo']
df_d2= df_d[df_d['lemma'].str.contains('|'.join(terms3), na=False)]
df_d2
# Out:
#                                                                                                           Texto de la pregunta  \
# 534   ¿Qué considera que el Grupo Ecopetrol debe dejar de hacer para fortalecer la vivencia de nuestros principios culturales?
# 2766  ¿Qué considera que el Grupo Ecopetrol debe dejar de hacer para fortalecer la vivencia de nuestros principios culturales?
# 3475  ¿Qué considera que el Grupo Ecopetrol debe dejar de hacer para fortalecer la vivencia de nuestros principios culturales?
# 3989  ¿Qué considera que el Grupo Ecopetrol debe dejar de hacer para fortalecer la vivencia de nuestros principios culturales?
# 4143  ¿Qué considera que el Grupo Ecopetrol debe dejar de hacer para fortalecer la vivencia de nuestros principios culturales?
# 7902  ¿Qué considera que el Grupo Ecopetrol debe dejar de hacer para fortalecer la vivencia de nuestros principios culturales?
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Comentario  \
# 534                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Respetar los horarios de trabajo de los funcionarios.
# 2766                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Respetar los horarios de trabajo, debe se runa regla de oro.
# 3475  No traer personal extranjero para liderar al interior de la Empresa, se cuenta con mucho material humano con experiencia para afrontar estos retos. Hacer la empresa más eficiente donde los trabajos que se desarrollan tengan y cumplan un objetivo y no caer en las nuevas modas mundiales donde todo se ha llenado de burocracia y de personas que solo buscan hacerse notar, creando procesos y procedimientos incomodos y complicados que no sirven para nada, esto lo fundamento en la experiencia de llevar muchos años y conocido muchas personas en el tiempo laborado en la empresa. Hay que optimizar el aprovechamiento del tiempo y que sea una cultura y no una moda, de la cual todos hablan pero nadie cumple. No se respetan los horarios de trabajo, no solo de las personas si no también institucionales, se deben organizar las reuniones, donde cada participante debe llevar preparado su discurso y exponerlo en un intervalo de tiempo prudente que esté entre 5 y 7 minutos máximo.
# 3989                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Respetemos los horarios de trabajo
# 4143                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Dejar de irrespetar los horarios de trabajo de las personas.  Trabajar mejor para el balance profesional y personal.  Confiar más en los trabajadores o mejorar sus indicadores de desempeño para tener mejor información sobre la gente que no desarrolla sus labores de manera satisfactoria para poder hacer renovación.\n\nExiste mucha gente que no hace nada y los equipos se extralimitan en horas y funciones para poder compensar ese tipo de personas.
# 7902                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Con todo el tema de virtualidad se debe respetar los horarios de trabajo y volver a laborar en campo.
#
#              Clasificación de comentarios    dup  \
# 534      Colaboración y trabajo en equipo  False
# 2766  Entorno laboral y trato al empleado  False
# 3475                  Innovación y cambio  False
# 3989  Entorno laboral y trato al empleado  False
# 4143  Entorno laboral y trato al empleado  False
# 7902  Entorno laboral y trato al empleado  False
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        lemma
# 534                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     respetar horario trabajo funcionario
# 2766                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           respetar horario trabajo deber runa regla oro
# 3475  traer personal extranjero liderar interior empresa contar material humano experiencia afrontar reto hacer empresa mas eficiente trabajo desarrollar cumplir objetivo caer nuevo modas mundial llenado burocracia persona solo buscar hacer él notar crear proceso procedimiento incomodo complicado servir fundamento experiencia llevar conocido mucho persona tiempo laborado empresa optimizar aprovechamiento tiempo cultura moda hablar nadie cumplir respetar horario trabajo solo persona si tambien institucional deber organizar reunión cada participante deber llevar preparado discurso exponer él intervalo tiempo prudente minuto maximo
# 3989                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                respetar horario trabajo
# 4143                                                                                                                                                                                                                                                                                                                               dejar irrespetar horario trabajo persona trabajar mejor balance profesional personal confiar mas trabajador mejorar indicador desempe tener mejor informacion gente desarrollar labor manera satisfactorio poder hacer renovacion existir mucho gente hacer equipo extralimitar hora función poder compensar tipo persona
# 7902                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    tema virtualidad deber respetar horario trabajo volver laborar campo

# %%
terms4 = ['vivir principio cultural']
df_c2= df_c[df_c['lemma'].str.contains('|'.join(terms4), na=False)]
df_c2
# Out:
#                                                                                                                              Texto de la pregunta  \
# 185   ¿Qué considera que el Grupo Ecopetrol debe empezar a hacer o seguir haciendo para fortalecer la vivencia de nuestros principios culturales?
# 3293  ¿Qué considera que el Grupo Ecopetrol debe empezar a hacer o seguir haciendo para fortalecer la vivencia de nuestros principios culturales?
# 4387  ¿Qué considera que el Grupo Ecopetrol debe empezar a hacer o seguir haciendo para fortalecer la vivencia de nuestros principios culturales?
# 5270  ¿Qué considera que el Grupo Ecopetrol debe empezar a hacer o seguir haciendo para fortalecer la vivencia de nuestros principios culturales?
# 6487  ¿Qué considera que el Grupo Ecopetrol debe empezar a hacer o seguir haciendo para fortalecer la vivencia de nuestros principios culturales?
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Comentario  \
# 185                                                                                                                                     El seguimiento de los principios culturales, como por ejemplo, por medio de la realización de encuestas de este tipo, es fundamental para identificar como se viven los principios culturales dentro del grupo empresarial Ecopetrol, por lo tanto, considero que se deben seguir realizando, con el fin de seguir fortaleciendo nuestra declaración cultural. Creo firmemente que el grupo empresarial y todos los empleados trabajamos día a día por vivir los principios culturales que nos hacen parte de esta gran familia.
# 3293                   Considero que Ecopetrol es un empresa que siempre esta a la vanguardia de las formas de hacer, que responde rápido a los cambios, esto relacionado con el talento humano que tiene muy instruido en el cambio, en la acción y la resiliencia. Creo que hemos avanzado muchísimo como empresa en vivir esos principios culturales, sin embargo, también creo que en ocasiones la presión por los resultados puede resultar de mayor importancia y esto hace que podamos tener un desbalance en lo laboral respecto a la vida personal que es tan importante para tener profesionales creativos, activos y que estén dando el 100% permanentemente.
# 4387                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Estimular aun mas la pasion de sus trabajadores por compartir y vivir los principios culturales de ecopetrol y hacerlo extensivos a sus entornos familiares
# 5270                                                                                                                                                                                                                                                                           Pienso que nuestro Grupo Ecopetrol tiene todas las herramientas para que las personas, sus trabajadores vivamos los principios culturales; quizás ayude presentarlos de forma diferente: un cuento, una pintura, un video real.\nHacer seguimiento al trabajador en todas las áreas: laboral, social, familiar, sicológica...\nActividades lúdicas, sociales, familiares, motivacionales.
# 6487  Considero que los principios culturales deben ser parte de nuestro diario vivir en la compañía. Por lo tanto, es necesario que los líderes hagan más énfasis en los mismos. No siento particularmente que ellos los sientan como parte de su ADN y por lo tanto no los transfieren a sus empleados a cargo. \nPor otro lado, creo que debe haber una reunión (virtual o presencial) donde se haga énfasis en la cultura de la compañía y con ejemplos se demuestre como vivimos nuestros principios culturales. Pero no a través de correo, sino en contacto con los líderes y demás equipos de la organización (algo así como un evento de integración cultural).
#
#                                   Clasificación de comentarios    dup  \
# 185                                    Orientación estratégica  False
# 3293                                       Innovación y cambio  False
# 4387  Procesos de trabajo, procedimientos y toma de decisiones  False
# 5270                       Entorno laboral y trato al empleado  False
# 6487                                            Comunicaciones  False
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                        lemma
# 185                                                                                    seguimiento principio cultural ejemplo medio realizacion encuesta tipo fundamental identificar vivir principio cultural dentro grupo empresarial ecopetrol considerar deber seguir realizar fin seguir fortalecer declaracion cultural creer firmemente grupo empresarial empleado trabajar dia dia vivir principio cultural hacer parte gran familia
# 3293  considerar ecopetrol empresa siempre vanguardia forma hacer responder rapido cambio relacionado talento humano instruido cambio accion resiliencia creer avanzado muchisimo empresa vivir principio cultural embargo tambien creer ocasión presion resultado poder resultar mayor importancia hacer poder tener desbalance laboral respecto vida personal tanto importante tener profesional creativo activo estar dar permanentemente
# 4387                                                                                                                                                                                                                                                                                                                   estimular aun mas pasion trabajador compartir vivir principio cultural ecopetrol hacer él extensivo entor yo familiar
# 5270                                                                                                                                                        pensar grupo ecopetrol todo herramienta persona trabajador vivir principio cultural quizas ayudar presentar él forma diferente cuento pintura video real hacer seguimiento trabajador todo area laboral social familiar sicologico actividad ludico social familiar motivacional
# 6487                                    considerar principio cultural deber ser parte diario vivir compa ia necesario lider hacer mas enfasis mismo sentir particularmente sentar parte adn transferir empleado cargo lado creer deber haber reunion virtual presencial hacer enfasis cultura compa ia ejemplo demostrar vivir principio cultural trave correo sino contacto lider demar equipo organizacion asi evento integracion cultural

# %%
with pd.ExcelWriter('Comentarios.xlsx') as writer1:
    df_c.to_excel(writer1, sheet_name='comenzar', index = False)
    df_d.to_excel(writer1, sheet_name='dejar', index = False)
